# %%
from algorithm.Random import choicerest as ArrayChoice
from collections import abc
from Graphy import GraphByVertex, Vertex
from numpy import random as rand
import cProfile
from memory_profiler import *
import numpy as np
import sys

"""
现在已经有了一个随机生成连接情况的图
下一步是上色。
最后可视化就再说了吧。

"""


colors = ['red', 'yellow', 'blue', 'green']#Enumeration...


def RandGenAdj(max_v, max_deg):

	"""
	max vertex  : max number of vertexes to be generated
	max degree : max number of linked vertex a vertex can have
	"""
	maxvset = set(list(range(max_v)))
	G = GraphByVertex(max_v)
	for idx in range(max_v):
		G.addVertex(Vertex(idx, 0, []))

	for idx in range(max_v):
		degree_per_v = rand.randint(0, max_deg)#每个节点的邻接节点数， 0个到max_deg个
		tmp = {idx}
		for i in range(degree_per_v):
			w = ArrayChoice(tmp, maxvset)
			tmp.add(w)
			G.addEdge(idx, w)
	return G

def RandGenAdj_LessZero(max_v, max_deg):
	"""
	上面的一种生成方式简单，但是可能生成过多的零邻接节点
	"""
	pass


def randfill(G:GraphByVertex):
	#Start the Process of filling
	for idx, clr in zip(G.G, rand.randint(1, 5, len(G))):
		G.set_colorof(idx.get_idx, clr)

def nearFilltry(G:GraphByVertex):
	#在速度要求下可以用这种方式生成，但这种可能导致找不到解
	for idx in range(len(G)):
		used_clr = G.linked_colors(idx) #used_clr is a list
		if used_clr is None:
			continue
		#print(used_clr)
		w = ArrayChoice(set(used_clr), {0, 1, 2, 3, 4})
		G.set_colorof(idx, w)

def fill4clr(G:GraphByVertex):
	#能找到优解
	degree_of_vertexes = G.idx_deg_mapping
	pass

#@profile
def main(maxVnum, maxDegNum):

	G = RandGenAdj(maxVnum, maxDegNum)
	nearFilltry(G)
	Gcount = G.count(by='v')
	print(f"{Gcount=}")
	print(f"{G.all_colors=}")
	#rint(G)






if __name__ == '__main__':
	cProfile.runctx('main(20, 3)', None, locals())
	for i in range(50):
		main(20, 3)
# Out:
# Gcount=20
# G.all_colors=[2, 4, 2, 4, 1, 3, 4, 3, 3, 4, 1, 2, 4, 2, 3, 1, 2, 0, 0, 4]
#          1742 function calls (1741 primitive calls) in 0.006 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        46    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(prod)
#         1    0.000    0.000    0.003    0.003 <ipython-input-4-820d00ce18b2>:21(RandGenAdj)
#         1    0.000    0.000    0.002    0.002 <ipython-input-4-820d00ce18b2>:53(nearFilltry)
#         1    0.000    0.000    0.006    0.006 <ipython-input-4-820d00ce18b2>:69(main)
#         1    0.000    0.000    0.006    0.006 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 Graphy.py:124(__init__)
#         1    0.000    0.000    0.000    0.000 Graphy.py:141(__len__)
#        20    0.000    0.000    0.000    0.000 Graphy.py:154(addVertex)
#        26    0.000    0.000    0.000    0.000 Graphy.py:170(addEdge)
#         1    0.000    0.000    0.000    0.000 Graphy.py:186(count)
#        20    0.000    0.000    0.000    0.000 Graphy.py:204(linked_colors)
#        20    0.000    0.000    0.000    0.000 Graphy.py:205(<setcomp>)
#        20    0.000    0.000    0.000    0.000 Graphy.py:214(set_colorof)
#         1    0.000    0.000    0.000    0.000 Graphy.py:225(all_colors)
#         1    0.000    0.000    0.000    0.000 Graphy.py:227(<listcomp>)
#        20    0.000    0.000    0.000    0.000 Graphy.py:47(__init__)
#        48    0.000    0.000    0.000    0.000 Graphy.py:64(addLinked)
#        20    0.000    0.000    0.000    0.000 Graphy.py:73(paint)
#        68    0.000    0.000    0.000    0.000 Graphy.py:91(get_color)
#       118    0.000    0.000    0.000    0.000 Graphy.py:94(get_linked)
#        46    0.000    0.000    0.000    0.000 Random.py:5(getrestlist)
#        46    0.000    0.000    0.004    0.000 Random.py:8(choicerest)
#        46    0.000    0.000    0.000    0.000 _collections_abc.py:392(__subclasshook__)
#        46    0.000    0.000    0.000    0.000 abc.py:100(__subclasscheck__)
#       138    0.000    0.000    0.000    0.000 abc.py:96(__instancecheck__)
#        46    0.000    0.000    0.000    0.000 fromnumeric.py:2907(_prod_dispatcher)
#        46    0.000    0.000    0.001    0.000 fromnumeric.py:2912(prod)
#        46    0.000    0.000    0.001    0.000 fromnumeric.py:70(_wrapreduction)
#        46    0.000    0.000    0.000    0.000 fromnumeric.py:71(<dictcomp>)
#         5    0.000    0.000    0.001    0.000 iostream.py:195(schedule)
#         4    0.000    0.000    0.000    0.000 iostream.py:308(_is_master_process)
#         4    0.000    0.000    0.000    0.000 iostream.py:321(_schedule_flush)
#         4    0.000    0.000    0.001    0.000 iostream.py:384(write)
#         5    0.000    0.000    0.000    0.000 iostream.py:91(_event_pipe)
#         5    0.000    0.000    0.000    0.000 socket.py:438(send)
#         5    0.000    0.000    0.000    0.000 threading.py:1017(_wait_for_tstate_lock)
#         5    0.000    0.000    0.000    0.000 threading.py:1071(is_alive)
#         5    0.000    0.000    0.000    0.000 threading.py:513(is_set)
#       138    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#        46    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         1    0.000    0.000    0.006    0.006 {built-in method builtins.exec}
#        46    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#       162    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#     51/50    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         2    0.000    0.000    0.001    0.000 {built-in method builtins.print}
#        46    0.000    0.000    0.001    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         4    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         5    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        26    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         5    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        68    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#        46    0.002    0.000    0.003    0.000 {method 'choice' of 'numpy.random.mtrand.RandomState' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        46    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        20    0.000    0.000    0.000    0.000 {method 'randint' of 'numpy.random.mtrand.RandomState' objects}
#        46    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
# --------------------------------------------------------------------
# ValueError                         Traceback (most recent call last)
# <ipython-input-4-820d00ce18b2> in <module>
#      84         cProfile.runctx('main(20, 3)', None, locals())
#      85         for i in range(50):
# ---> 86                 main(20, 3)
#
# <ipython-input-4-820d00ce18b2> in main(maxVnum, maxDegNum)
#      70
#      71         G = RandGenAdj(maxVnum, maxDegNum)
# ---> 72         nearFilltry(G)
#      73         Gcount = G.count(by='v')
#      74         print(f"{Gcount=}")
#
# <ipython-input-4-820d00ce18b2> in nearFilltry(G)
#      58                         continue
#      59                 #print(used_clr)
# ---> 60                 w = ArrayChoice(set(used_clr), {0, 1, 2, 3, 4})
#      61                 G.set_colorof(idx, w)
#      62
#
# /mnt/d/sourcecodes/git/four-colors/test/algorithm/Random.py in choicerest(used, src)
#      13                 raise TypeError("Wrong Error, Need (MutableSequence/Set, Container")
#      14         rest = getrestlist(used_set, src_set)
# ---> 15         return rand.choice(rest)
#      16
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: 'a' cannot be empty unless no samples are taken
